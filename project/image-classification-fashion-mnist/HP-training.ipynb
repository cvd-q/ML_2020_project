# %%
import sys
sys.path.append('/kaggle/input/ml-project-2020-dataset/')
from sklearn.metrics import roc_auc_score #FORGOT
import os
os.mkdir('/kaggle/working/logs/')
os.mkdir('/kaggle/working/checkpoint/')
os.mkdir('/kaggle/working/logs/InceptionResnet_test/')

# %% [markdown]
# > # TRAINING

# %%
from test_dataset import *
# Out:
# HP --->   REDUCE_SIZE-1 DROP_RATE-0.5 LR-0.001 OPTIMIZER-adam
# Epoch 1/6
# 1563/1563 - 235s - loss: 1.0882 - accuracy: 0.5868 - val_loss: 1.4155 - val_accuracy: 0.4639
# Epoch 2/6
# 1563/1563 - 230s - loss: 0.6403 - accuracy: 0.7649 - val_loss: 0.8993 - val_accuracy: 0.6862
# Epoch 3/6
# 1563/1563 - 229s - loss: 0.5314 - accuracy: 0.8262 - val_loss: 1.0373 - val_accuracy: 0.6205
# Epoch 4/6
# 1563/1563 - 228s - loss: 0.4650 - accuracy: 0.8503 - val_loss: 1.1615 - val_accuracy: 0.6483
# Epoch 5/6
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1563/1563 - 228s - loss: 0.4192 - accuracy: 0.8640 - val_loss: 0.8908 - val_accuracy: 0.6819
# Epoch 6/6
# 1563/1563 - 229s - loss: 0.3253 - accuracy: 0.8946 - val_loss: 0.8545 - val_accuracy: 0.6896
#
# Label:  T-shirt/top ,  AUROC one vs rest =  0.5
# Label:  Trouser ,  AUROC one vs rest =  0.5
# Label:  Pullover ,  AUROC one vs rest =  0.5
# Label:  Dress ,  AUROC one vs rest =  0.5
# ...
